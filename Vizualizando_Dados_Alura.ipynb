# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Whit3/Vizualizando-Dados---Alura/blob/main/Vizualizando_Dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Vizualizando dados - Alura

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
df.set_index('País', inplace=True)

# %%
anos = list(map(str, range(1980, 2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brasil', anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
brasil_dict = {'ano': brasil.index.tolist(), 'imigrantes': brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.title('Imigrantes do Brasil para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010', '2014'])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='r')
ax.set_title('Imigrantes do Brasil para o Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('Imigração_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigrantes do Brasil para o Canadá\n1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot dos imigrantes do Brasil para o Canadá')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Número de imigrantes')
axs[1].grid()

plt.show()

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
fig, axs = plt.subplots(2,2, figsize=(15, 10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Imigração dos quatro maiores países da Ámerica do Sul para o Canadá de 1980 a 2013')

axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat:
    ax.set_xlabel('Ano')
    ax.set_ylabel('Número de Imigrantes')

ymin = 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

plt.show()

# %%
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %%
america_sul = df.query('Região == "América do Sul"')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
america_sul_sorted = america_sul.sort_values('Total', ascending=False)

# %%
cores = []
for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores.append('g')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize=(12,5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('América do Sul: Brasil foi o país com mais imigrantes\npara o Canadá de 1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

fig.savefig('imigração_america_sul.png', transparent=False, dpi=300, bbox_inches='tight')
plt.show()

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, x='Total', y=top_10.index, palette='ch:start=.2,rot=-.3')
# Out:
# /tmp/ipython-input-1290391074.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, x='Total', y=top_10.index, palette='ch:start=.2,rot=-.3')
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='ch:start=.2,rot=-.3')

ax.set(title='Países com maior imigração para o canadá\n1980 a 2013',
      xlabel='Número de Imigrantes',
      ylabel=''
  )

plt.show()
# Out:
# /tmp/ipython-input-4225049172.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='ch:start=.2,rot=-.3')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='ch:start=.2,rot=-.3_r')

ax.set_title('Países com maior imigração para o canadá\n1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')
# Out:
# /tmp/ipython-input-850094045.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='ch:start=.2,rot=-.3_r')
# Text(0, 0.5, '')

# %%
def gerar_grafico_paleta(palette):
  fig, ax = plt.subplots(figsize=(8,4))
  ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)
  ax.set_title('Países com maior imigração para o canadá\n1980 a 2013', loc='left', fontsize=16)
  ax.set_xlabel('Número de Imigrantes', fontsize=14)
  ax.set_ylabel('')

  plt.show()

# %%
gerar_grafico_paleta('Blues')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('Blues_r')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('rocket')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('coolwarm')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-3969573860.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette=palette)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='tab10')

ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
sns.despine()

plt.show()
# Out:
# /tmp/ipython-input-917810019.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='tab10')

# %%
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes',
              title='Imigrantes do Brasil para o Canadá de 1980 a 2013')
fig.update_traces(line_color='blue', line_width=4)
fig.update_layout(width=1000, height=500,
                  xaxis={'tickangle':-45},
                  font_family='Arial',
                  font_size=14,
                  font_color='grey',
                  title_font_color='black',
                  title_font_size=22,
                  xaxis_title='Ano',
                  yaxis_title='Número de Imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
america_sul.head()
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
#
#            1984  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Argentina   237   196   213   519  ...  1153   847   620   540   467   459
# Bolívia      38    44    79   165  ...   134   139   107   143   214   180
# Brasil      145   130   205   244  ...   969  1181  1746  2138  2509  2598
# Chile       681   533   633  1454  ...   384   427   530   350   375   340
# Colômbia    235   214   257   376  ...  6424  6535  5357  5452  4652  5218
#
# ...

# %%
df_america_sul_clean = america_sul.drop(['Continente', 'Região', 'Total'], axis=1)
america_sul_final = df_america_sul_clean.T

# %%
america_sul_final.head()
# Out:
# País  Argentina  Bolívia  Brasil  Chile  Colômbia  Equador  Guiana  Paraguai  \
# 1980        368       44     211   1233       266      238    2334        45
# 1981        426       52     220   1069       326      207    2943        26
# 1982        626       42     192   1078       360      184    3575        32
# 1983        241       49     139    781       244      155    2650        40
# 1984        237       38     145    681       235      179    1932        48
#
# País  Peru  Suriname  Uruguai  Venezuela
# 1980   317        15      128        103
# 1981   456        10      132        117
# 1982   401        21      146        174
# 1983   241        12      105        124
# 1984   306         5       90        142

# %%
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País',
            title='Imigração dos países da américa do sul para o Canadá de 1980 a 2013', markers=True)

fig.update_layout(
    xaxis={'tickangle': -45},
    xaxis_title='Ano',
    yaxis_title='Número de Imigrantes'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dados_brasil['ano'] = dados_brasil['ano'].astype(int)

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(x=[dados_brasil['ano'].iloc[0]], y=[dados_brasil['imigrantes'].iloc[0]], mode='lines', name='Imigrantes', line=dict(width=4))
    )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil para o Canadá no período de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
     updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1000,
    height=500
)
frames = [go.Frame(data=[go.Scatter(x=dados_brasil['ano'].iloc[:i+1], y=dados_brasil['imigrantes'].iloc[:i+1])]) for i in range(len(dados_brasil))]
fig.frames = frames

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Imersão em Dados 3 - Crie Gráficos e conte histórias com Dados

# %%
dataframe_limpo.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2436436777.py in <cell line: 0>()
# ----> 1 dataframe_limpo.head()
#
# NameError: name 'dataframe_limpo' is not defined

# %%
dataframe_limpo['senioridade'].value_counts().plot(kind='bar', title='Distribuição de Senioriedade')

# %%
import seaborn as sns

# %%
sns.barplot(data=dataframe_limpo, x='senioridade', y='usd')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=dataframe_limpo, x='senioridade', y='usd')
plt.title('Salário por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Médio anual (USD)')
plt.show()

# %%
dataframe_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)

# %%
ordem = dataframe_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index

# %%
ordem

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=dataframe_limpo, x='senioridade', y='usd', order=ordem)
plt.title('Salário por senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário Médio anual (USD)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(dataframe_limpo['usd'], bins=50, kde=False)
plt.title('Distribuição dos Salários Anuais')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=dataframe_limpo['usd'])
plt.title("Boxplot dos Salários Anuais")
plt.xlabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Júnior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(10,5))
sns.boxplot(x='senioridade', y='usd', data=dataframe_limpo, order=ordem_senioridade)
plt.title("Boxplot da distribuição por Senioridade")
plt.xlabel('Senioridade')
plt.ylabel('Salário em USD')
plt.show()

# %%
ordem_senioridade = ['Júnior', 'Pleno', 'Senior', 'Executivo']

plt.figure(figsize=(10,5))
sns.boxplot(x='senioridade', y='usd', data=dataframe_limpo, order=ordem_senioridade, palette='Set1', hue='senioridade')
plt.title("Boxplot da distribuição por Senioridade")
plt.xlabel('Senioridade')
plt.ylabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# %%
salario_por_senioridade = dataframe_limpo.groupby('senioridade')['usd'].mean().reset_index()

ordem_senioridade = ['Júnior', 'Pleno', 'Senior', 'Executivo']
salario_por_senioridade['senioridade'] = pd.Categorical(salario_por_senioridade['senioridade'], categories=ordem_senioridade, ordered=True)
salario_por_senioridade = salario_por_senioridade.sort_values('senioridade')

fig = px.bar(salario_por_senioridade, x='senioridade', y='usd',
             title='Média Salarial por Senioridade (USD)',
             labels={'senioridade': 'Senioridade', 'usd': 'Média Salarial Anual (USD)'})

fig.update_layout(xaxis={'categoryorder':'array', 'categoryarray':ordem_senioridade})

fig.show()

# %%
remoto_contagem = dataframe_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='proporção dos tipos de trabalho'
)

fig.show()

# %%
remoto_contagem = dataframe_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='proporção dos tipos de trabalho',
             hole=0.5
)

fig.show()

# %%
remoto_contagem = dataframe_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='proporção dos tipos de trabalho',
             hole=0.5
)

fig.update_traces(textinfo='percent+label')

fig.show()

# %%
dataframe_cientista_dados = dataframe_limpo[dataframe_limpo['cargo'] == 'Data Scientist']

# Calculate the count of Data Scientists per country and select the top 10
contagem_por_residencia = dataframe_cientista_dados['residencia'].value_counts().nlargest(10).reset_index()
contagem_por_residencia.columns = ['residencia', 'quantidade_cientistas_dados']

# Get the average salary for these top 10 countries
salario_medio_top_10 = dataframe_cientista_dados[dataframe_cientista_dados['residencia'].isin(contagem_por_residencia['residencia'])].groupby('residencia')['usd'].mean().reset_index()

# Merge the count and average salary dataframes
dados_plot = pd.merge(contagem_por_residencia, salario_medio_top_10, on='residencia')

# Sort by average salary in descending order for plotting (highest to lowest)
dados_plot = dados_plot.sort_values('usd', ascending=False)

# Create a dictionary to map country codes to full names (in Portuguese)
country_names = {
    'LT': 'Lituânia',
    'AU': 'Austrália',
    'FR': 'França',
    'AT': 'Áustria',
    'DE': 'Alemanha',
    'ES': 'Espanha',
    'NL': 'Holanda',
    'GB': 'Reino Unido',
    'CA': 'Canadá',
    'US': 'Estados Unidos'
}

fig = px.bar(dados_plot, x='residencia', y='usd',
             title='Média Salarial para Cientistas de Dados nos Top 10 Países (USD)',
             labels={'residencia': 'País de Residência', 'usd': 'Média Salarial Anual (USD)'},
             text='quantidade_cientistas_dados') # Add text labels for the count

# Update layout to show full country names below abbreviations, ordered by salary
fig.update_layout(
    xaxis={
        'categoryorder': 'array',
        'categoryarray': dados_plot['residencia'].tolist(),
        'tickmode': 'array',
        'tickvals': dados_plot['residencia'].tolist(),
        'ticktext': [f"{code}<br>({country_names.get(code, code)})" for code in dados_plot['residencia'].tolist()]
    }
)

fig.show()

# %%
import pycountry
#Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
  try:
    return pycountry.countries.get(alpha_2=code).alpha_3
  except:
    return None

#Criar nova coluna com código ISO-3
dataframe_limpo['residencia_iso3'] = dataframe_limpo['residencia'].apply(iso2_to_iso3)

#Calcular média salarial por país (ISO-3)
df_ds = dataframe_limpo[dataframe_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')["usd"].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
fig.show()

# %%
dataframe_limpo.to_csv('dados_imersão-final.csv', index=False)

# %% [markdown]
# # Imersão em Dados 2 - Preparação e limpeza dos dados

# %%
dataframe.isnull().sum()

# %%
dataframe["ano"].unique()

# %%
dataframe[dataframe.isnull().any(axis=1)]

# %%
import numpy as np

#Criação de dataframe de testes
dataframe_salarios = pd.DataFrame({
    "Nome": ["Ana" , "Bruno" , "Dusantos", "Serguei", "Cirilo", "Kennedy"],
    "Salário": [4000, np.nan, 5000, 100000, np.nan, np.nan]
})

#calcula a media salarial e substitui os nulos pela média e arredonda os valores
dataframe_salarios['salario_media'] = dataframe_salarios['Salário'].fillna(dataframe_salarios['Salário'].mean().round(2))

'''Calcula mediana e substitui os nulos pela mediana'''

dataframe_salarios['salario_mediana'] = dataframe_salarios['Salário'].fillna(dataframe_salarios['Salário'].median())

dataframe_salarios

# %%
dataframe_temperaturas = pd.DataFrame({
    'Dia': ["segunda", "terça", "quarta", "quinta", "sexta"],
    'Temperatura': [30, np.nan, np.nan, 28, 27]

})

dataframe_temperaturas["Preenchido_ffill"] = dataframe_temperaturas["Temperatura"].ffill()
dataframe_temperaturas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3847164930.py in <cell line: 0>()
#       1 dataframe_temperaturas = pd.DataFrame({
#       2     'Dia': ["segunda", "terça", "quarta", "quinta", "sexta"],
# ----> 3     'Temperatura': [30, np.nan, np.nan, 28, 27]
#       4
#       5 })
#
# NameError: name 'np' is not defined

# %%
dataframe_temperaturas = pd.DataFrame({
    'Dia': ["segunda", "terça", "quarta", "quinta", "sexta"],
    'Temperatura': [30, np.nan, np.nan, 28, 27]

})

dataframe_temperaturas["Preenchido_ffill"] = dataframe_temperaturas["Temperatura"].ffill()
dataframe_temperaturas

# %%
dataframe_temperaturas = pd.DataFrame({
    'Dia': ["segunda", "terça", "quarta", "quinta", "sexta"],
    'Temperatura': [30, np.nan, np.nan, 28, 27]

})

dataframe_temperaturas["Preenchido_bfill"] = dataframe_temperaturas["Temperatura"].bfill()
dataframe_temperaturas

# %%
#Transformando valores nulos em um único valor: "não informado"
dataframe_cidades = pd.DataFrame({
    "Nome": ["Ana" , "Bruno" , "Dusantos", "Serguei", "Cirilo", "Kennedy"],
    "Cidade": ["São Paulo", np.nan, "Campinas", np.nan, "Salgadeiro do Norte", np.nan]

})

dataframe_cidades['cidade_preenchida'] = dataframe_cidades["Cidade"].fillna("Não informado")
dataframe_cidades

# %%
dataframe_limpo = dataframe.dropna()

# %%
dataframe_limpo.isnull().sum()

# %%
dataframe_limpo.head()

# %%
 dataframe_limpo.info()

# %%
dataframe_limpo = dataframe_limpo.assign(ano = dataframe_limpo["ano"].astype('int64'))

# %% [markdown]
# # Imersão em Dados 1 - Análise de Dados com Pandas

# %%
import pandas as pd

dataframe = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

dataframe.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
dataframe.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
dataframe.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = dataframe.shape[0], dataframe.shape[1]
print("Linhas é igual a:", linhas)
print("Colunas é igual a:", colunas)
# Out:
# Linhas é igual a: 133349
# Colunas é igual a: 11

# %%
# Traduzindo os nomes das colunas para português
dataframe.columns = ['ano', 'senioridade', 'conntrato', 'cargo', 'salario', 'moeda', 'usd', 'residencia', 'remoto', 'empresa', 'tamanho_empresa']

# Exibindo as colunas traduzidas para verificar
print(dataframe.columns)
# Out:
# Index(['ano', 'senioridade', 'conntrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
dataframe["ano"].value_counts()
# Out:
# ano
# 2024.0    62240
# 2025.0    60627
# 2023.0     8521
# 2022.0     1660
# 2021.0      216
# 2020.0       75
# Name: count, dtype: int64

# %%
# Traduzindo as categorias da coluna 'senioridade'
senioridade = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

dataframe['senioridade'] = dataframe['senioridade'].replace(senioridade)

# Exibindo os valores únicos na coluna 'senioridade' para verificar
print(dataframe['senioridade'].unique())
# Out:
# ['Senior' 'Pleno' 'Júnior' 'Executivo']

# %%
dataframe["senioridade"].value_counts()
# Out:
# senioridade
# Senior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
dataframe.head()
# Out:
#       ano senioridade conntrato               cargo  salario moeda     usd  \
# 0  2025.0      Senior        FT  Solutions Engineer   214000   USD  214000
# 1  2025.0      Senior        FT  Solutions Engineer   136000   USD  136000
# 2  2025.0       Pleno        FT       Data Engineer   158800   USD  158800
# 3  2025.0       Pleno        FT       Data Engineer   139200   USD  139200
# 4  2025.0      Júnior        FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
# Traduzindo as categorias da coluna 'remoto'
traducao_remoto = {
    100: 'Remoto',
    50: 'Híbrido',
    0: 'Presencial'
}

dataframe['remoto'] = dataframe['remoto'].map(traducao_remoto)

# Exibindo os valores únicos na coluna 'remoto' para verificar
print(dataframe['remoto'].unique())
# Out:
# ['Remoto' 'Presencial' 'Híbrido']

# %%
dataframe.describe(include='object')
# Out:
#        senioridade conntrato           cargo   moeda residencia      remoto  \
# count       133349    133349          133349  133349     133349      133349
# unique           4         4             390      26        102           3
# top         Senior        FT  Data Scientist     USD         US  Presencial
# freq         77241    132563           17314  126140     119579      105312
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US               M
# freq    119641          129561

# %% [markdown]
# # Aula - Introdução a Data Science

# %%
import pandas as pd

# %%
Notas_vizualizadas = pd.read_csv('/content/ratings.csv').groupby('userId').size().sort_values(ascending=False)
top_10_users = Notas_vizualizadas.head(10)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
top_10_users.plot(kind='bar')
plt.title('Top 10 Users by Number of Ratings')
plt.xlabel('User ID')
plt.ylabel('Number of Ratings')
plt.xticks(rotation=5)
plt.tight_layout()
plt.show()

# %%
Notas = pd.read_csv('/content/ratings.csv')

# %%
Notas['rating'].mean()
# Out:
# np.float64(3.501556983616962)

# %%
Notas['rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd

# Criando um DataFrame simples
dados = { 'Nome': ['Mirla', 'Ana', 'Daniel'],
   'Idade': [25, 30, 35],
              'Salario': [5000, 6000, 8000]}
df = pd.DataFrame(dados)
df
# Out:
#      Nome  Idade  Salario
# 0   Mirla     25     5000
# 1     Ana     30     6000
# 2  Daniel     35     8000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nome     3 non-null      object
#  1   Idade    3 non-null      int64
#  2   Salario  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
df['Salario'].mean()
# ou df.Salario.mean()
# Out:
# np.float64(6333.333333333333)

# %%
import pandas as pd

# Criando um Series simples
idades = pd.Series([45, 30, 45, 40, 25])
idades
# Out:
# 0    45
# 1    30
# 2    45
# 3    40
# 4    25
# dtype: int64

# %%
idades.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
idades.sort_values()
# Out:
# 4    25
# 1    30
# 3    40
# 0    45
# 2    45
# dtype: int64

# %%
notas = pd.read_csv("ratings.csv")
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique()
notas['nota'].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas["nota"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
sns.boxplot(notas["nota"])
# Out:
# <Axes: ylabel='nota'>

# %%
print("Média das notas:", notas['nota'].mean())
print("Mediana das notas:", notas['nota'].median())
print("\nResumo descritivo das notas:")
print(notas['nota'].describe())
# Out:
# Média das notas: 3.501556983616962
# Mediana das notas: 3.5
#
# Resumo descritivo das notas:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
Média_Notas = notas['nota'].mean()
Mediana_notas = notas['nota'].median()

# %%
print (f"a média das notas é {Média_Notas}")
print (f"a mediana das notas é {Mediana_notas}")
# Out:
# a média das notas é 3.501556983616962
# a mediana das notas é 3.5

# %%
filmes = pd.read_csv("/content/movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.query("filmeId==1")['nota'].mean()
# Out:
# np.float64(3.9209302325581397)

# %%
medias_por_filme = notas.groupby('filmeId')["nota"].mean()
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
sns.displot(medias_por_filme, kde=True)

# %%
tmdb = pd.read_csv("/content/tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
sns.displot(tmdb["revenue"])
plt.title("Distribuição da receita")
plt.show()

# %%
sns.displot(tmdb["budget"])
plt.title("Distribuição do orçamento")
plt.show()

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
tmdb.query('revenue > 0')
sns.displot(tmdb.query('revenue > 0')["revenue"])
plt.title("Distribuição da receita")
plt.show()

# %%
tmdb['original_language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
contagem_de_lingua = tmdb['original_language'].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ['original_language', 'total']
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
contagem_de_lingua.plot()
# Out:
# <Axes: >

# %%
sns.barplot(data = contagem_de_lingua, x='original_language', y='total')
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.countplot(data=tmdb, x='original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
contagem_de_lingua.plot(kind='pie', y='total',figsize=(5,5), labels=contagem_de_lingua['original_language'])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc['en']
total_do_resto = total_geral - total_de_ingles
print(total_geral, total_de_ingles, total_do_resto)
# Out:
# 4803 4505 298

# %%
dados = {
'lingua' : ['ingles', 'outros'],
'total' : [total_de_ingles, total_do_resto]

}
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dados['total'].plot(kind='hist', bins=20, title='total')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# dados.groupby('lingua').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dados['total'].plot(kind='line', figsize=(8, 4), title='total')
# ...

# %%
sns.barplot(data=dados, x='lingua', y='total')
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
dados.plot(kind='pie', y='total', labels=dados['lingua'], autopct='%1.1f%%')
# Out:
# <Axes: ylabel='total'>

# %%
total_de_outros_filmes_por_língua = tmdb.query("original_language != 'en'")["original_language"].value_counts()

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"), x='original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns

# Importando a base de dados
tmdb = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/tmdb_5000_movies.csv")

# Filtrando os dados para as colunas desejadas
dados = tmdb[["title", "original_language", "budget", "revenue"]]
linguas = ["fr", "es", "de"]

# Mantendo dados com valores de receita e orçamento válidos e nas línguas desejadas (fr, es, de)
fr_es_de_com_revenue_e_budget = dados.query("revenue > 0 and budget > 0 and original_language == @linguas")

# Construindo o gráfico de dispersão mais a reta de regressão linear para cada caso
sns.lmplot(data=fr_es_de_com_revenue_e_budget, x="budget", y="revenue", col="original_language",
           hue="original_language", ci=None, height=4, scatter_kws={"s": 30, "alpha": 0.5})

# %%
plt.figure(figsize=(10, 2))
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order=total_de_outros_filmes_por_língua.index,
              hue = 'original_language',
              palette = 'mako',
              stat='percent',
              hue_order = total_de_outros_filmes_por_língua.index,
              x='original_language'
)
plt.title("Distribuição de filmes por língua exceto em Inglês")
# Out:
# Text(0.5, 1.0, 'Distribuição de filmes por língua exceto em Inglês')

# %%
total_de_outros_filmes_por_lingua = tmdb.query("original_language != 'en'")["original_language"].value_counts()
total_de_outros_filmes_por_lingua.head()
plt.figure(figsize=(16, 8))
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order=total_de_outros_filmes_por_lingua.index,
              palette="mako",
              hue="original_language",
              hue_order=total_de_outros_filmes_por_lingua.index,
              stat="percent",
              x="original_language")
plt.title("Distribuição da língua original nos filmes exceto em inglês")
plt.show()

# %%
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Get the first two movie IDs from the 'filmes' DataFrame
notas_do_toy_story = notas.query("filmeId==1")['nota']
notas_do_jumanji = notas.query("filmeId==2")['nota']

plt.boxplot([notas_do_toy_story, notas_do_jumanji])
plt.show()

# %%
sns.boxplot(data=notas.query("filmeId in [1,2,3,4,5,6,7,8]"),
            x='filmeId',
            y='nota',
            palette='mako',
          )
# Out:
# /tmp/ipython-input-745111677.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=notas.query("filmeId in [1,2,3,4,5,6,7,8]"),
# <Axes: xlabel='filmeId', ylabel='nota'>

# %%
notas["filmeId"].value_counts().tail()
# Out:
# filmeId
# 188833    1
# 189381    1
# 3899      1
# 2848      1
# 147002    1
# Name: count, dtype: int64

# %%
notas.groupby('filmeId').count().query("nota >= 1")
# Out:
#          usuarioId  nota  momento
# filmeId
# 1              215   215      215
# 2              110   110      110
# 3               52    52       52
# 4                7     7        7
# 5               49    49       49
# ...            ...   ...      ...
# 193581           1     1        1
# 193583           1     1        1
# 193585           1     1        1
# 193587           1     1        1
# 193609           1     1        1
#
# [9724 rows x 3 columns]

# %%
notas_do_grumpier_old_men = notas.query("filmeId==3")["nota"]

# Boxplot com Matplotlib
plt.boxplot([notas_do_toy_story, notas_do_jumanji, notas_do_grumpier_old_men])

# Boxplot com Seaborn
sns.boxplot(data=notas.query("filmeId in [1,2,3]"), x="filmeId", y="nota", palette="Set2")
# Out:
# /tmp/ipython-input-1483021611.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=notas.query("filmeId in [1,2,3]"), x="filmeId", y="nota", palette="Set2")
# <Axes: xlabel='filmeId', ylabel='nota'>

# %%
preco = 49.98765
print("O preço do produto é: {:.2f}".format(preco))
print(f"O preço do produto é: {preco:.2f}")

salario = float(input("Digite o seu salário: "))
print(f"Seu salário é R$ {salario:.2f}.")
# Out:
# O preço do produto é: 49.99
# O preço do produto é: 49.99
# Digite o seu salário: 102532
# Seu salário é R$ 102532.00.
